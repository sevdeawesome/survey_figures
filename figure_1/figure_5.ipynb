# %%
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from utils import *

plt.style.use('../style.mplstyle')
df = pd.read_csv("../latest.csv")

# %%
df = fix_data(df, drop_zeros=False)

# %%
print("length of df: ", len(df))
print('\n')
df.head(1)
# Out:
# length of df:  106
#              StartDate  reading  Duration  Progress  Finished    Q42  \
# 0  2024-08-08 23:30:29        7       118       100      True  Agree
#
#            Q43        Q1  Q1_7_TEXT   Q2  ...           Q16_3           Q16_4  \
# 0  LinkedIn DM  Industry        NaN  2.0  ...  Somewhat agree  Somewhat agree
#
#             Q16_5           Q16_6           Q16_7           Q16_8  \
# 0  Somewhat agree  Somewhat agree  Somewhat agree  Somewhat agree
#
#             Q16_9  Q17  Q18  Q46
# 0  Somewhat agree  NaN  NaN  NaN
#
# [1 rows x 41 columns]

# %% [markdown]
# # how agreeable is each article

# %%
df
# Out:
#                StartDate  reading  Duration  Progress  Finished    Q42  \
# 0    2024-08-08 23:30:29        7       118       100      True  Agree
# 1    2024-08-09 23:28:38        7       282       100      True  Agree
# 2    2024-08-10 16:03:37        9       269       100      True  Agree
# 3    2024-08-11 22:38:37        7       286       100      True  Agree
# 4     2024-08-12 1:16:00       13      1058       100      True  Agree
# ..                   ...      ...       ...       ...       ...    ...
# 101  2024-08-22 10:38:58        0       262        17     False  Agree
# 102   2024-08-23 4:35:11        9       289        72     False  Agree
# 103   2024-08-29 6:34:31       11      2624        72     False  Agree
# 104   2024-08-27 3:46:15        0    578941        17     False  Agree
# 105  2024-09-10 17:48:40        7       163       100      True  Agree
#
#                         Q43        Q1  Q1_7_TEXT   Q2  ...              Q16_3  \
# 0               LinkedIn DM  Industry        NaN  2.0  ...     Somewhat agree
# 1               LinkedIn DM  Industry        NaN  2.0  ...  strongly disagree
# 2                     Email  Academic        NaN  5.0  ...  strongly disagree
# 3               LinkedIn DM  Industry        NaN  2.0  ...     Somewhat agree
# 4               LinkedIn DM  Industry        NaN  5.0  ...  Somewhat disagree
# ..                      ...       ...        ...  ...  ...                ...
# 101                   Email       NaN        NaN  NaN  ...                NaN
# 102                   Email  Academic        NaN  2.0  ...                NaN
# 103                   Email  Academic        NaN  5.0  ...                NaN
# 104  Discord/Slack/other DM       NaN        NaN  NaN  ...                NaN
# 105                   Email  Academic        NaN  4.0  ...  Somewhat disagree
#
#                           Q16_4                       Q16_5  \
# 0                Somewhat agree              Somewhat agree
# 1             Somewhat disagree              Somewhat agree
# 2    Neither agree nor disagree  Neither agree nor disagree
# 3             Somewhat disagree  Neither agree nor disagree
# 4    Neither agree nor disagree              Somewhat agree
# ..                          ...                         ...
# 101                         NaN                         NaN
# 102                         NaN                         NaN
# 103                         NaN                         NaN
# 104                         NaN                         NaN
# 105           Somewhat disagree           Somewhat disagree
#
#                  Q16_6                       Q16_7  \
# 0       Somewhat agree              Somewhat agree
# 1    Somewhat disagree  Neither agree nor disagree
# 2       Somewhat agree  Neither agree nor disagree
# 3    Somewhat disagree              Somewhat agree
# 4    strongly disagree  Neither agree nor disagree
# ..                 ...                         ...
# 101                NaN                         NaN
# 102                NaN                         NaN
# 103                NaN                         NaN
# 104                NaN                         NaN
# 105  Somewhat disagree           Somewhat disagree
#
#                           Q16_8           Q16_9  \
# 0                Somewhat agree  Somewhat agree
# 1                Somewhat agree  Strongly agree
# 2    Neither agree nor disagree  Somewhat agree
# 3             strongly disagree  Strongly agree
# 4             Somewhat disagree  Strongly agree
# ..                          ...             ...
# 101                         NaN             NaN
# 102                         NaN             NaN
# 103                         NaN             NaN
# 104                         NaN             NaN
# 105           strongly disagree  Somewhat agree
#
#                                                    Q17  Q18  Q46
# 0                                                  NaN  NaN  NaN
# 1                                                  NaN  NaN  NaN
# 2    We do not need ti reach AGI to already have so...  NaN  NaN
# 3    That it will not affect people's daily lives. ...  NaN  NaN
# 4                                                  NaN  NaN  NaN
# ..                                                 ...  ...  ...
# 101                                                NaN  NaN  NaN
# 102                                                NaN  NaN  NaN
# 103                                                NaN  NaN  NaN
# 104                                                NaN  NaN  NaN
# 105                                                NaN  NaN  NaN
#
# [106 rows x 41 columns]

# %%
df['reading'] = df['reading'].replace(7, "Control")
df['reading'] = df['reading'].replace(9, "Russel")
df['reading'] = df['reading'].replace(11, "Joy")
df['reading'] = df['reading'].replace(13, "Aschenbrenner")
# get Q15 and df[reading] into a new dataframe
df_agreement = df[['Q15', 'reading']]

# %%
# drop the rows with NaN values in Q15
df_agreement = df_agreement.dropna(subset=['Q15'])

# drop the rows with 0 in reading
df_agreement = df_agreement[df_agreement['reading'] != 0]

# %%
# replace the values in Q15 with numerical values (1-5)
df_agreement['Q15'] = df_agreement['Q15'].replace({
    'Strongly disagree': 1,
    'Somewhat disagree': 2,
    'Neither agree nor disagree': 3,
    'Somewhat agree': 4,
    'Strongly agree': 5
})

# %%
df_agreement['reading'].value_counts()
# Out:
# Control          23
# Aschenbrenner    17
# Joy              12
# Russel           11
# Name: reading, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter out NaN values and sort by 'number'
# df_filtered = df_agreement.dropna(subset=['Q15']).sort_values('reading')

# Create the plot
plt.figure(figsize=(12, 6))
sns.barplot(x='reading', y='Q15', data=df_agreement, palette='viridis')

# Customize the plot
plt.title('Article Agreeability Scores')
plt.xlabel('Article Number')
plt.ylabel('Agreeability Score')
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
df['Q1']
# Out:
# 0      Industry
# 1      Industry
# 2      Academic
# 3      Industry
# 4      Industry
#          ...
# 101         NaN
# 102    Academic
# 103    Academic
# 104         NaN
# 105    Academic
# Name: Q1, Length: 106, dtype: object
